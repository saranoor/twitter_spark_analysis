# %%
pip install sagemaker -U
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: sagemaker in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (2.126.0)
# Requirement already satisfied: pathos in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from sagemaker) (0.2.8)
# Requirement already satisfied: boto3<2.0,>=1.26.28 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from sagemaker) (1.26.35)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from sagemaker) (21.3)
# Requirement already satisfied: pandas in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from sagemaker) (1.3.4)
# Requirement already satisfied: protobuf3-to-dict<1.0,>=0.1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from sagemaker) (0.1.5)
# Requirement already satisfied: numpy<2.0,>=1.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from sagemaker) (1.20.3)
# Requirement already satisfied: attrs<23,>=20.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from sagemaker) (21.2.0)
# Requirement already satisfied: schema in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from sagemaker) (0.7.5)
# Requirement already satisfied: google-pasta in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from sagemaker) (0.2.0)
# Requirement already satisfied: importlib-metadata<5.0,>=1.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from sagemaker) (4.8.2)
# Requirement already satisfied: protobuf<4.0,>=3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from sagemaker) (3.19.1)
# Requirement already satisfied: smdebug-rulesconfig==1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from sagemaker) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from boto3<2.0,>=1.26.28->sagemaker) (0.6.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from boto3<2.0,>=1.26.28->sagemaker) (0.10.0)
# Requirement already satisfied: botocore<1.30.0,>=1.29.35 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from boto3<2.0,>=1.26.28->sagemaker) (1.29.39)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from importlib-metadata<5.0,>=1.4.0->sagemaker) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from packaging>=20.0->sagemaker) (3.0.6)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from protobuf3-to-dict<1.0,>=0.1.5->sagemaker) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from pandas->sagemaker) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from pandas->sagemaker) (2021.3)
# Requirement already satisfied: dill>=0.3.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from pathos->sagemaker) (0.3.4)
# Requirement already satisfied: ppft>=1.6.6.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from pathos->sagemaker) (1.6.6.4)
# Requirement already satisfied: multiprocess>=0.70.12 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from pathos->sagemaker) (0.70.12.2)
# Requirement already satisfied: pox>=0.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from pathos->sagemaker) (0.3.0)
# Requirement already satisfied: contextlib2>=0.5.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from schema->sagemaker) (21.6.0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from botocore<1.30.0,>=1.29.35->boto3<2.0,>=1.26.28->sagemaker) (1.26.8)
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import sagemaker
session = sagemaker.Session()

# role = sagemaker.get_execution_role()
# print("RoleArn: {}".format(role))

# %%
region = sagemaker.Session().boto_region_name
print("AWS Region: {}".format(region))

role = sagemaker.get_execution_role()
print("RoleArn: {}".format(role))
# Out:
# AWS Region: us-east-1
# RoleArn: arn:aws:iam::432547830124:role/service-role/AmazonSageMaker-ExecutionRole-20221229T184597

# %%
import boto3

# %%
bucket_name = sagemaker.Session().default_bucket()

# %%
# set an output path where the trained model will be saved
prefix = 'xgboost-as-a-built-in-algo'
output_path ='s3://{}/{}/output'.format(bucket_name, prefix)
print(output_path)
# Out:
# s3://sagemaker-us-east-1-432547830124/xgboost-as-a-built-in-algo/output

# %%
import pandas as pd
import urllib
try:
    urllib.request.urlretrieve ("https://d1.awsstatic.com/tmt/build-train-deploy-machine-learning-model-sagemaker/bank_clean.27f01fbbdf43271788427f3682996ae29ceca05d.csv", "bank_clean.csv")
    print('Success: downloaded bank_clean.csv.')
except Exception as e:
    print('Data load error: ',e)

try:
    model_data = pd.read_csv('./bank_clean.csv',index_col=0)
    print('Success: Data loaded into dataframe.')
except Exception as e:
    print('Data load error: ',e)
# Out:
# Success: downloaded bank_clean.csv.
# Success: Data loaded into dataframe.

# %%
### Train Test split

import numpy as np
train_data, test_data = np.split(model_data.sample(frac=1, random_state=1729), [int(0.7 * len(model_data))])
print(train_data.shape, test_data.shape)
# Out:
# (28831, 61) (12357, 61)

# %%
### Saving Train And Test Into Buckets
## We start with Train Data
import os
pd.concat([train_data['y_yes'], train_data.drop(['y_no', 'y_yes'], 
                                                axis=1)], 
                                                axis=1).to_csv('train.csv', index=False, header=False)
boto3.Session().resource('s3').Bucket(bucket_name).Object(os.path.join(prefix, 'train/train.csv')).upload_file('train.csv')
#s3_input_train = sagemaker.s3_input(s3_data='s3://{}/{}/train'.format(bucket_name, prefix), content_type='csv')

# %%
# Test Data Into Buckets
pd.concat([test_data['y_yes'], test_data.drop(['y_no', 'y_yes'], axis=1)], axis=1).to_csv('test.csv', index=False, header=False)
boto3.Session().resource('s3').Bucket(bucket_name).Object(os.path.join(prefix, 'test/test.csv')).upload_file('test.csv')

# %%
s3_input_train = sagemaker.TrainingInput(s3_data='s3://{}/{}/train'.format(bucket_name, prefix), content_type='csv')

# %%
s3_input_test = sagemaker.TrainingInput(s3_data='s3://{}/{}/test'.format(bucket_name, prefix), content_type='csv')

# %%
s3_output_location='s3://{}/{}/{}'.format(bucket_name, prefix, 'xg_model')

# %%
container= sagemaker.image_uris.retrieve("xgboost", region, "1.2-1")

# %%
#print(container)
from sagemaker.debugger import Rule, rule_configs

s3_output_location='s3://{}/{}/{}'.format(bucket_name, prefix, 'xgboost_model')

xgb_model=sagemaker.estimator.Estimator(
    image_uri=container,
    role=role,
    instance_count=1,
    instance_type='ml.m4.xlarge',
    volume_size=5,
    output_path=s3_output_location,
    sagemaker_session=sagemaker.Session(),
    rules=[Rule.sagemaker(rule_configs.create_xgboost_report())]
)

# %%
xgb_model.set_hyperparameters(
    max_depth = 5,
    eta = 0.2,
    gamma = 4,
    min_child_weight = 6,
    subsample = 0.7,
    objective = "binary:logistic",
    num_round = 1000
)

# %%
xgb_model.fit({"train":s3_input_train, "validation":s3_input_test},wait=True)
# Out:
# INFO:sagemaker:Creating training-job with name: sagemaker-xgboost-2022-12-29-16-11-47-930
# 2022-12-29 16:11:48 Starting - Starting the training job...CreateXgboostReport: InProgress
# ...
# 2022-12-29 16:12:32 Starting - Preparing the instances for training.........
# 2022-12-29 16:14:12 Downloading - Downloading input data...
# 2022-12-29 16:14:37 Training - Downloading the training image...
# 2022-12-29 16:15:13 Training - Training image download completed. Training in progress...[2022-12-29 16:15:26.129 ip-10-0-81-126.ec2.internal:7 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# INFO:sagemaker-containers:Imported framework sagemaker_xgboost_container.training
# INFO:sagemaker-containers:Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# INFO:sagemaker-containers:No GPUs detected (normal if no gpus installed)
# INFO:sagemaker_xgboost_container.training:Running XGBoost Sagemaker in algorithm mode
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Single node training.
# [2022-12-29 16:15:26.323 ip-10-0-81-126.ec2.internal:7 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2022-12-29 16:15:26.324 ip-10-0-81-126.ec2.internal:7 INFO hook.py:199] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2022-12-29 16:15:26.324 ip-10-0-81-126.ec2.internal:7 INFO profiler_config_parser.py:102] User has disabled profiler.
# [2022-12-29 16:15:26.325 ip-10-0-81-126.ec2.internal:7 INFO hook.py:253] Saving to /opt/ml/output/tensors
# [2022-12-29 16:15:26.325 ip-10-0-81-126.ec2.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# INFO:root:Debug hook created from config
# INFO:root:Train matrix has 28831 rows and 59 columns
# INFO:root:Validation matrix has 12357 rows
# [0]#011train-error:0.10079#011validation-error:0.10528
# [2022-12-29 16:15:26.389 ip-10-0-81-126.ec2.internal:7 INFO hook.py:413] Monitoring the collections: hyperparameters, predictions, metrics, feature_importance, labels
# [2022-12-29 16:15:26.392 ip-10-0-81-126.ec2.internal:7 INFO hook.py:476] Hook is writing from the hook with pid: 7
# [1]#011train-error:0.09968#011validation-error:0.10456
# [2]#011train-error:0.10017#011validation-error:0.10375
# [3]#011train-error:0.09989#011validation-error:0.10310
# [4]#011train-error:0.09996#011validation-error:0.10286
# [5]#011train-error:0.09906#011validation-error:0.10261
# [6]#011train-error:0.09930#011validation-error:0.10286
# [7]#011train-error:0.09951#011validation-error:0.10261
# [8]#011train-error:0.09920#011validation-error:0.10286
# [9]#011train-error:0.09871#011validation-error:0.10294
# [10]#011train-error:0.09868#011validation-error:0.10294
# [11]#011train-error:0.09868#011validation-error:0.10326
# [12]#011train-error:0.09854#011validation-error:0.10358
# [13]#011train-error:0.09892#011validation-error:0.10342
# [14]#011train-error:0.09850#011validation-error:0.10342
# [15]#011train-error:0.09844#011validation-error:0.10326
# [16]#011train-error:0.09857#011validation-error:0.10318
# [17]#011train-error:0.09799#011validation-error:0.10318
# [18]#011train-error:0.09816#011validation-error:0.10383
# [19]#011train-error:0.09857#011validation-error:0.10383
# [20]#011train-error:0.09830#011validation-error:0.10350
# [21]#011train-error:0.09826#011validation-error:0.10318
# [22]#011train-error:0.09847#011validation-error:0.10399
# [23]#011train-error:0.09833#011validation-error:0.10407
# [24]#011train-error:0.09812#011validation-error:0.10415
# [25]#011train-error:0.09812#011validation-error:0.10399
# [26]#011train-error:0.09774#011validation-error:0.10375
# [27]#011train-error:0.09781#011validation-error:0.10375
# [28]#011train-error:0.09781#011validation-error:0.10391
# [29]#011train-error:0.09778#011validation-error:0.10367
# [30]#011train-error:0.09781#011validation-error:0.10383
# [31]#011train-error:0.09771#011validation-error:0.10358
# [32]#011train-error:0.09743#011validation-error:0.10391
# [33]#011train-error:0.09753#011validation-error:0.10342
# [34]#011train-error:0.09767#011validation-error:0.10342
# [35]#011train-error:0.09757#011validation-error:0.10350
# [36]#011train-error:0.09757#011validation-error:0.10342
# [37]#011train-error:0.09736#011validation-error:0.10342
# [38]#011train-error:0.09750#011validation-error:0.10342
# [39]#011train-error:0.09733#011validation-error:0.10350
# [40]#011train-error:0.09705#011validation-error:0.10358
# [41]#011train-error:0.09701#011validation-error:0.10383
# [42]#011train-error:0.09712#011validation-error:0.10407
# [43]#011train-error:0.09698#011validation-error:0.10375
# [44]#011train-error:0.09733#011validation-error:0.10342
# [45]#011train-error:0.09736#011validation-error:0.10367
# [46]#011train-error:0.09746#011validation-error:0.10350
# [47]#011train-error:0.09736#011validation-error:0.10358
# [48]#011train-error:0.09712#011validation-error:0.10334
# [49]#011train-error:0.09712#011validation-error:0.10318
# [50]#011train-error:0.09729#011validation-error:0.10318
# [51]#011train-error:0.09719#011validation-error:0.10310
# [52]#011train-error:0.09722#011validation-error:0.10302
# [53]#011train-error:0.09705#011validation-error:0.10286
# [54]#011train-error:0.09701#011validation-error:0.10286
# [55]#011train-error:0.09712#011validation-error:0.10294
# [56]#011train-error:0.09705#011validation-error:0.10278
# [57]#011train-error:0.09667#011validation-error:0.10278
# [58]#011train-error:0.09660#011validation-error:0.10286
# [59]#011train-error:0.09618#011validation-error:0.10302
# [60]#011train-error:0.09663#011validation-error:0.10286
# [61]#011train-error:0.09632#011validation-error:0.10310
# [62]#011train-error:0.09611#011validation-error:0.10286
# [63]#011train-error:0.09597#011validation-error:0.10261
# [64]#011train-error:0.09594#011validation-error:0.10245
# [65]#011train-error:0.09583#011validation-error:0.10213
# [66]#011train-error:0.09559#011validation-error:0.10261
# [67]#011train-error:0.09524#011validation-error:0.10261
# [68]#011train-error:0.09535#011validation-error:0.10261
# [69]#011train-error:0.09528#011validation-error:0.10261
# [70]#011train-error:0.09517#011validation-error:0.10253
# [71]#011train-error:0.09521#011validation-error:0.10302
# [72]#011train-error:0.09517#011validation-error:0.10286
# [73]#011train-error:0.09511#011validation-error:0.10294
# [74]#011train-error:0.09493#011validation-error:0.10286
# [75]#011train-error:0.09490#011validation-error:0.10302
# [76]#011train-error:0.09500#011validation-error:0.10294
# [77]#011train-error:0.09493#011validation-error:0.10278
# [78]#011train-error:0.09511#011validation-error:0.10302
# [79]#011train-error:0.09507#011validation-error:0.10302
# [80]#011train-error:0.09511#011validation-error:0.10334
# [81]#011train-error:0.09497#011validation-error:0.10310
# [82]#011train-error:0.09486#011validation-error:0.10350
# [83]#011train-error:0.09493#011validation-error:0.10318
# [84]#011train-error:0.09469#011validation-error:0.10399
# [85]#011train-error:0.09455#011validation-error:0.10423
# [86]#011train-error:0.09452#011validation-error:0.10399
# [87]#011train-error:0.09455#011validation-error:0.10358
# [88]#011train-error:0.09472#011validation-error:0.10367
# [89]#011train-error:0.09486#011validation-error:0.10375
# [90]#011train-error:0.09479#011validation-error:0.10383
# [91]#011train-error:0.09479#011validation-error:0.10383
# [92]#011train-error:0.09483#011validation-error:0.10383
# [93]#011train-error:0.09493#011validation-error:0.10367
# [94]#011train-error:0.09479#011validation-error:0.10342
# [95]#011train-error:0.09438#011validation-error:0.10383
# [96]#011train-error:0.09403#011validation-error:0.10391
# [97]#011train-error:0.09406#011validation-error:0.10464
# [98]#011train-error:0.09396#011validation-error:0.10431
# [99]#011train-error:0.09438#011validation-error:0.10431
# [100]#011train-error:0.09441#011validation-error:0.10423
# [101]#011train-error:0.09410#011validation-error:0.10399
# [102]#011train-error:0.09406#011validation-error:0.10399
# [103]#011train-error:0.09431#011validation-error:0.10399
# [104]#011train-error:0.09441#011validation-error:0.10399
# [105]#011train-error:0.09410#011validation-error:0.10415
# [106]#011train-error:0.09400#011validation-error:0.10407
# [107]#011train-error:0.09403#011validation-error:0.10439
# [108]#011train-error:0.09386#011validation-error:0.10399
# [109]#011train-error:0.09406#011validation-error:0.10407
# [110]#011train-error:0.09410#011validation-error:0.10407
# [111]#011train-error:0.09424#011validation-error:0.10391
# [112]#011train-error:0.09438#011validation-error:0.10391
# [113]#011train-error:0.09413#011validation-error:0.10407
# [114]#011train-error:0.09424#011validation-error:0.10480
# [115]#011train-error:0.09406#011validation-error:0.10496
# [116]#011train-error:0.09410#011validation-error:0.10496
# [117]#011train-error:0.09389#011validation-error:0.10512
# [118]#011train-error:0.09400#011validation-error:0.10464
# [119]#011train-error:0.09396#011validation-error:0.10480
# [120]#011train-error:0.09355#011validation-error:0.10431
# [121]#011train-error:0.09372#011validation-error:0.10447
# [122]#011train-error:0.09362#011validation-error:0.10431
# [123]#011train-error:0.09368#011validation-error:0.10456
# [124]#011train-error:0.09375#011validation-error:0.10464
# [125]#011train-error:0.09362#011validation-error:0.10480
# [126]#011train-error:0.09372#011validation-error:0.10447
# [127]#011train-error:0.09372#011validation-error:0.10447
# [128]#011train-error:0.09372#011validation-error:0.10447
# [129]#011train-error:0.09355#011validation-error:0.10464
# [130]#011train-error:0.09341#011validation-error:0.10447
# [131]#011train-error:0.09330#011validation-error:0.10464
# [132]#011train-error:0.09334#011validation-error:0.10464
# [133]#011train-error:0.09323#011validation-error:0.10447
# [134]#011train-error:0.09330#011validation-error:0.10464
# [135]#011train-error:0.09323#011validation-error:0.10472
# [136]#011train-error:0.09316#011validation-error:0.10496
# [137]#011train-error:0.09309#011validation-error:0.10496
# [138]#011train-error:0.09302#011validation-error:0.10488
# [139]#011train-error:0.09316#011validation-error:0.10456
# [140]#011train-error:0.09337#011validation-error:0.10480
# [141]#011train-error:0.09351#011validation-error:0.10504
# [142]#011train-error:0.09344#011validation-error:0.10496
# [143]#011train-error:0.09344#011validation-error:0.10496
# [144]#011train-error:0.09341#011validation-error:0.10512
# [145]#011train-error:0.09313#011validation-error:0.10537
# [146]#011train-error:0.09313#011validation-error:0.10537
# [147]#011train-error:0.09309#011validation-error:0.10553
# [148]#011train-error:0.09316#011validation-error:0.10553
# [149]#011train-error:0.09292#011validation-error:0.10569
# [150]#011train-error:0.09289#011validation-error:0.10569
# [151]#011train-error:0.09302#011validation-error:0.10537
# [152]#011train-error:0.09306#011validation-error:0.10545
# [153]#011train-error:0.09299#011validation-error:0.10569
# [154]#011train-error:0.09299#011validation-error:0.10569
# [155]#011train-error:0.09295#011validation-error:0.10577
# [156]#011train-error:0.09275#011validation-error:0.10569
# [157]#011train-error:0.09275#011validation-error:0.10585
# [158]#011train-error:0.09292#011validation-error:0.10553
# [159]#011train-error:0.09285#011validation-error:0.10561
# [160]#011train-error:0.09271#011validation-error:0.10545
# [161]#011train-error:0.09261#011validation-error:0.10528
# [162]#011train-error:0.09261#011validation-error:0.10528
# [163]#011train-error:0.09251#011validation-error:0.10496
# [164]#011train-error:0.09264#011validation-error:0.10504
# [165]#011train-error:0.09247#011validation-error:0.10504
# [166]#011train-error:0.09244#011validation-error:0.10480
# [167]#011train-error:0.09254#011validation-error:0.10480
# [168]#011train-error:0.09247#011validation-error:0.10496
# [169]#011train-error:0.09240#011validation-error:0.10545
# [170]#011train-error:0.09230#011validation-error:0.10537
# [171]#011train-error:0.09247#011validation-error:0.10553
# [172]#011train-error:0.09230#011validation-error:0.10561
# [173]#011train-error:0.09219#011validation-error:0.10585
# [174]#011train-error:0.09244#011validation-error:0.10569
# [175]#011train-error:0.09257#011validation-error:0.10569
# [176]#011train-error:0.09244#011validation-error:0.10520
# [177]#011train-error:0.09257#011validation-error:0.10520
# [178]#011train-error:0.09261#011validation-error:0.10561
# [179]#011train-error:0.09240#011validation-error:0.10577
# [180]#011train-error:0.09233#011validation-error:0.10577
# [181]#011train-error:0.09230#011validation-error:0.10569
# [182]#011train-error:0.09233#011validation-error:0.10569
# [183]#011train-error:0.09202#011validation-error:0.10569
# [184]#011train-error:0.09143#011validation-error:0.10545
# [185]#011train-error:0.09129#011validation-error:0.10553
# [186]#011train-error:0.09133#011validation-error:0.10553
# [187]#011train-error:0.09136#011validation-error:0.10545
# [188]#011train-error:0.09122#011validation-error:0.10545
# [189]#011train-error:0.09126#011validation-error:0.10553
# [190]#011train-error:0.09143#011validation-error:0.10561
# [191]#011train-error:0.09122#011validation-error:0.10553
# [192]#011train-error:0.09133#011validation-error:0.10553
# [193]#011train-error:0.09146#011validation-error:0.10569
# [194]#011train-error:0.09150#011validation-error:0.10585
# [195]#011train-error:0.09153#011validation-error:0.10569
# [196]#011train-error:0.09146#011validation-error:0.10553
# [197]#011train-error:0.09133#011validation-error:0.10585
# [198]#011train-error:0.09140#011validation-error:0.10593
# [199]#011train-error:0.09160#011validation-error:0.10561
# [200]#011train-error:0.09150#011validation-error:0.10561
# [201]#011train-error:0.09153#011validation-error:0.10561
# [202]#011train-error:0.09160#011validation-error:0.10561
# [203]#011train-error:0.09140#011validation-error:0.10577
# [204]#011train-error:0.09164#011validation-error:0.10569
# [205]#011train-error:0.09157#011validation-error:0.10577
# [206]#011train-error:0.09129#011validation-error:0.10593
# [207]#011train-error:0.09126#011validation-error:0.10577
# [208]#011train-error:0.09129#011validation-error:0.10569
# [209]#011train-error:0.09129#011validation-error:0.10601
# [210]#011train-error:0.09140#011validation-error:0.10634
# [211]#011train-error:0.09153#011validation-error:0.10609
# [212]#011train-error:0.09153#011validation-error:0.10626
# [213]#011train-error:0.09153#011validation-error:0.10626
# [214]#011train-error:0.09153#011validation-error:0.10618
# [215]#011train-error:0.09140#011validation-error:0.10585
# [216]#011train-error:0.09115#011validation-error:0.10577
# [217]#011train-error:0.09115#011validation-error:0.10577
# [218]#011train-error:0.09119#011validation-error:0.10577
# [219]#011train-error:0.09129#011validation-error:0.10593
# [220]#011train-error:0.09122#011validation-error:0.10577
# [221]#011train-error:0.09136#011validation-error:0.10577
# [222]#011train-error:0.09122#011validation-error:0.10585
# [223]#011train-error:0.09122#011validation-error:0.10585
# [224]#011train-error:0.09122#011validation-error:0.10585
# [225]#011train-error:0.09108#011validation-error:0.10585
# [226]#011train-error:0.09091#011validation-error:0.10626
# [227]#011train-error:0.09087#011validation-error:0.10634
# [228]#011train-error:0.09105#011validation-error:0.10642
# [229]#011train-error:0.09101#011validation-error:0.10634
# [230]#011train-error:0.09098#011validation-error:0.10634
# [231]#011train-error:0.09087#011validation-error:0.10609
# [232]#011train-error:0.09084#011validation-error:0.10650
# [233]#011train-error:0.09074#011validation-error:0.10650
# [234]#011train-error:0.09101#011validation-error:0.10609
# [235]#011train-error:0.09053#011validation-error:0.10650
# [236]#011train-error:0.09074#011validation-error:0.10650
# [237]#011train-error:0.09070#011validation-error:0.10618
# [238]#011train-error:0.09074#011validation-error:0.10601
# [239]#011train-error:0.09060#011validation-error:0.10618
# [240]#011train-error:0.09056#011validation-error:0.10626
# [241]#011train-error:0.09063#011validation-error:0.10658
# [242]#011train-error:0.09053#011validation-error:0.10682
# [243]#011train-error:0.09087#011validation-error:0.10682
# [244]#011train-error:0.09094#011validation-error:0.10690
# [245]#011train-error:0.09074#011validation-error:0.10690
# [246]#011train-error:0.09042#011validation-error:0.10658
# [247]#011train-error:0.09032#011validation-error:0.10674
# [248]#011train-error:0.09032#011validation-error:0.10666
# [249]#011train-error:0.09042#011validation-error:0.10634
# [250]#011train-error:0.09032#011validation-error:0.10626
# [251]#011train-error:0.09056#011validation-error:0.10658
# [252]#011train-error:0.09053#011validation-error:0.10650
# [253]#011train-error:0.09056#011validation-error:0.10650
# [254]#011train-error:0.09053#011validation-error:0.10658
# [255]#011train-error:0.09039#011validation-error:0.10666
# [256]#011train-error:0.09025#011validation-error:0.10690
# [257]#011train-error:0.09032#011validation-error:0.10674
# [258]#011train-error:0.09029#011validation-error:0.10698
# [259]#011train-error:0.09035#011validation-error:0.10698
# [260]#011train-error:0.09022#011validation-error:0.10723
# [261]#011train-error:0.09018#011validation-error:0.10731
# [262]#011train-error:0.09018#011validation-error:0.10731
# [263]#011train-error:0.09008#011validation-error:0.10747
# [264]#011train-error:0.08990#011validation-error:0.10706
# [265]#011train-error:0.08990#011validation-error:0.10706
# [266]#011train-error:0.09004#011validation-error:0.10715
# [267]#011train-error:0.09015#011validation-error:0.10690
# [268]#011train-error:0.09018#011validation-error:0.10690
# [269]#011train-error:0.09015#011validation-error:0.10674
# [270]#011train-error:0.09022#011validation-error:0.10658
# [271]#011train-error:0.09008#011validation-error:0.10658
# [272]#011train-error:0.09004#011validation-error:0.10674
# [273]#011train-error:0.09004#011validation-error:0.10658
# [274]#011train-error:0.09015#011validation-error:0.10658
# [275]#011train-error:0.09022#011validation-error:0.10658
# [276]#011train-error:0.09001#011validation-error:0.10666
# [277]#011train-error:0.08997#011validation-error:0.10658
# [278]#011train-error:0.08997#011validation-error:0.10698
# [279]#011train-error:0.09008#011validation-error:0.10690
# [280]#011train-error:0.09001#011validation-error:0.10690
# [281]#011train-error:0.09001#011validation-error:0.10690
# [282]#011train-error:0.09004#011validation-error:0.10666
# [283]#011train-error:0.09008#011validation-error:0.10674
# [284]#011train-error:0.09011#011validation-error:0.10690
# [285]#011train-error:0.09008#011validation-error:0.10682
# [286]#011train-error:0.08997#011validation-error:0.10658
# [287]#011train-error:0.08997#011validation-error:0.10682
# [288]#011train-error:0.08994#011validation-error:0.10690
# [289]#011train-error:0.09015#011validation-error:0.10682
# [290]#011train-error:0.09015#011validation-error:0.10706
# [291]#011train-error:0.08990#011validation-error:0.10690
# [292]#011train-error:0.08976#011validation-error:0.10698
# [293]#011train-error:0.08956#011validation-error:0.10674
# [294]#011train-error:0.08956#011validation-error:0.10650
# [295]#011train-error:0.08952#011validation-error:0.10666
# [296]#011train-error:0.08949#011validation-error:0.10658
# [297]#011train-error:0.08949#011validation-error:0.10674
# [298]#011train-error:0.08952#011validation-error:0.10674
# [299]#011train-error:0.08956#011validation-error:0.10706
# [300]#011train-error:0.08966#011validation-error:0.10682
# [301]#011train-error:0.08963#011validation-error:0.10698
# [302]#011train-error:0.08959#011validation-error:0.10698
# [303]#011train-error:0.08949#011validation-error:0.10690
# [304]#011train-error:0.08949#011validation-error:0.10698
# [305]#011train-error:0.08963#011validation-error:0.10690
# [306]#011train-error:0.08966#011validation-error:0.10666
# [307]#011train-error:0.08942#011validation-error:0.10706
# [308]#011train-error:0.08942#011validation-error:0.10698
# [309]#011train-error:0.08942#011validation-error:0.10698
# [310]#011train-error:0.08966#011validation-error:0.10706
# [311]#011train-error:0.08963#011validation-error:0.10698
# [312]#011train-error:0.08966#011validation-error:0.10698
# [313]#011train-error:0.08973#011validation-error:0.10698
# [314]#011train-error:0.08963#011validation-error:0.10698
# [315]#011train-error:0.08976#011validation-error:0.10715
# [316]#011train-error:0.08963#011validation-error:0.10715
# [317]#011train-error:0.08969#011validation-error:0.10731
# [318]#011train-error:0.08969#011validation-error:0.10731
# [319]#011train-error:0.08980#011validation-error:0.10731
# [320]#011train-error:0.08966#011validation-error:0.10715
# [321]#011train-error:0.08952#011validation-error:0.10723
# [322]#011train-error:0.08956#011validation-error:0.10723
# [323]#011train-error:0.08963#011validation-error:0.10731
# [324]#011train-error:0.08966#011validation-error:0.10731
# [325]#011train-error:0.08966#011validation-error:0.10723
# [326]#011train-error:0.08956#011validation-error:0.10698
# [327]#011train-error:0.08949#011validation-error:0.10698
# [328]#011train-error:0.08956#011validation-error:0.10715
# [329]#011train-error:0.08942#011validation-error:0.10723
# [330]#011train-error:0.08935#011validation-error:0.10723
# [331]#011train-error:0.08938#011validation-error:0.10715
# [332]#011train-error:0.08921#011validation-error:0.10715
# [333]#011train-error:0.08911#011validation-error:0.10706
# [334]#011train-error:0.08914#011validation-error:0.10698
# [335]#011train-error:0.08924#011validation-error:0.10723
# [336]#011train-error:0.08921#011validation-error:0.10706
# [337]#011train-error:0.08928#011validation-error:0.10739
# [338]#011train-error:0.08924#011validation-error:0.10731
# [339]#011train-error:0.08949#011validation-error:0.10666
# [340]#011train-error:0.08931#011validation-error:0.10698
# [341]#011train-error:0.08931#011validation-error:0.10682
# [342]#011train-error:0.08928#011validation-error:0.10674
# [343]#011train-error:0.08928#011validation-error:0.10682
# [344]#011train-error:0.08938#011validation-error:0.10650
# [345]#011train-error:0.08938#011validation-error:0.10658
# [346]#011train-error:0.08938#011validation-error:0.10666
# [347]#011train-error:0.08938#011validation-error:0.10666
# [348]#011train-error:0.08938#011validation-error:0.10634
# [349]#011train-error:0.08942#011validation-error:0.10658
# [350]#011train-error:0.08942#011validation-error:0.10658
# [351]#011train-error:0.08942#011validation-error:0.10658
# [352]#011train-error:0.08942#011validation-error:0.10658
# [353]#011train-error:0.08956#011validation-error:0.10618
# [354]#011train-error:0.08952#011validation-error:0.10601
# [355]#011train-error:0.08956#011validation-error:0.10601
# [356]#011train-error:0.08956#011validation-error:0.10601
# [357]#011train-error:0.08945#011validation-error:0.10618
# [358]#011train-error:0.08942#011validation-error:0.10658
# [359]#011train-error:0.08935#011validation-error:0.10650
# [360]#011train-error:0.08938#011validation-error:0.10650
# [361]#011train-error:0.08938#011validation-error:0.10658
# [362]#011train-error:0.08935#011validation-error:0.10650
# [363]#011train-error:0.08924#011validation-error:0.10642
# [364]#011train-error:0.08911#011validation-error:0.10618
# [365]#011train-error:0.08904#011validation-error:0.10626
# [366]#011train-error:0.08924#011validation-error:0.10626
# [367]#011train-error:0.08924#011validation-error:0.10626
# [368]#011train-error:0.08921#011validation-error:0.10658
# [369]#011train-error:0.08921#011validation-error:0.10650
# [370]#011train-error:0.08911#011validation-error:0.10658
# [371]#011train-error:0.08921#011validation-error:0.10666
# [372]#011train-error:0.08921#011validation-error:0.10666
# [373]#011train-error:0.08928#011validation-error:0.10690
# [374]#011train-error:0.08935#011validation-error:0.10682
# [375]#011train-error:0.08938#011validation-error:0.10658
# [376]#011train-error:0.08938#011validation-error:0.10658
# [377]#011train-error:0.08921#011validation-error:0.10642
# [378]#011train-error:0.08924#011validation-error:0.10650
# [379]#011train-error:0.08924#011validation-error:0.10666
# [380]#011train-error:0.08911#011validation-error:0.10682
# [381]#011train-error:0.08897#011validation-error:0.10698
# [382]#011train-error:0.08890#011validation-error:0.10674
# [383]#011train-error:0.08893#011validation-error:0.10682
# [384]#011train-error:0.08904#011validation-error:0.10690
# [385]#011train-error:0.08904#011validation-error:0.10682
# [386]#011train-error:0.08907#011validation-error:0.10674
# [387]#011train-error:0.08935#011validation-error:0.10674
# [388]#011train-error:0.08914#011validation-error:0.10682
# [389]#011train-error:0.08924#011validation-error:0.10674
# [390]#011train-error:0.08924#011validation-error:0.10674
# [391]#011train-error:0.08938#011validation-error:0.10658
# [392]#011train-error:0.08942#011validation-error:0.10690
# [393]#011train-error:0.08931#011validation-error:0.10682
# [394]#011train-error:0.08924#011validation-error:0.10666
# [395]#011train-error:0.08914#011validation-error:0.10690
# [396]#011train-error:0.08918#011validation-error:0.10706
# [397]#011train-error:0.08907#011validation-error:0.10698
# [398]#011train-error:0.08907#011validation-error:0.10706
# [399]#011train-error:0.08907#011validation-error:0.10698
# [400]#011train-error:0.08914#011validation-error:0.10706
# [401]#011train-error:0.08907#011validation-error:0.10698
# [402]#011train-error:0.08911#011validation-error:0.10715
# [403]#011train-error:0.08914#011validation-error:0.10723
# [404]#011train-error:0.08914#011validation-error:0.10715
# [405]#011train-error:0.08911#011validation-error:0.10706
# [406]#011train-error:0.08918#011validation-error:0.10698
# [407]#011train-error:0.08904#011validation-error:0.10674
# [408]#011train-error:0.08907#011validation-error:0.10674
# [409]#011train-error:0.08900#011validation-error:0.10706
# [410]#011train-error:0.08914#011validation-error:0.10706
# [411]#011train-error:0.08911#011validation-error:0.10706
# [412]#011train-error:0.08918#011validation-error:0.10690
# [413]#011train-error:0.08914#011validation-error:0.10690
# [414]#011train-error:0.08907#011validation-error:0.10682
# [415]#011train-error:0.08907#011validation-error:0.10690
# [416]#011train-error:0.08904#011validation-error:0.10690
# [417]#011train-error:0.08900#011validation-error:0.10690
# [418]#011train-error:0.08876#011validation-error:0.10723
# [419]#011train-error:0.08869#011validation-error:0.10723
# [420]#011train-error:0.08869#011validation-error:0.10723
# [421]#011train-error:0.08862#011validation-error:0.10731
# [422]#011train-error:0.08862#011validation-error:0.10739
# [423]#011train-error:0.08855#011validation-error:0.10723
# [424]#011train-error:0.08858#011validation-error:0.10715
# [425]#011train-error:0.08858#011validation-error:0.10715
# [426]#011train-error:0.08865#011validation-error:0.10723
# [427]#011train-error:0.08872#011validation-error:0.10715
# [428]#011train-error:0.08872#011validation-error:0.10715
# [429]#011train-error:0.08869#011validation-error:0.10731
# [430]#011train-error:0.08872#011validation-error:0.10755
# [431]#011train-error:0.08876#011validation-error:0.10747
# [432]#011train-error:0.08879#011validation-error:0.10763
# [433]#011train-error:0.08869#011validation-error:0.10771
# [434]#011train-error:0.08865#011validation-error:0.10787
# [435]#011train-error:0.08865#011validation-error:0.10795
# [436]#011train-error:0.08872#011validation-error:0.10779
# [437]#011train-error:0.08848#011validation-error:0.10747
# [438]#011train-error:0.08852#011validation-error:0.10747
# [439]#011train-error:0.08848#011validation-error:0.10747
# [440]#011train-error:0.08869#011validation-error:0.10763
# [441]#011train-error:0.08855#011validation-error:0.10771
# [442]#011train-error:0.08855#011validation-error:0.10771
# [443]#011train-error:0.08852#011validation-error:0.10763
# [444]#011train-error:0.08852#011validation-error:0.10763
# [445]#011train-error:0.08848#011validation-error:0.10763
# [446]#011train-error:0.08865#011validation-error:0.10755
# [447]#011train-error:0.08855#011validation-error:0.10755
# [448]#011train-error:0.08855#011validation-error:0.10763
# [449]#011train-error:0.08883#011validation-error:0.10739
# [450]#011train-error:0.08876#011validation-error:0.10739
# [451]#011train-error:0.08883#011validation-error:0.10739
# [452]#011train-error:0.08886#011validation-error:0.10755
# [453]#011train-error:0.08883#011validation-error:0.10755
# [454]#011train-error:0.08858#011validation-error:0.10739
# [455]#011train-error:0.08855#011validation-error:0.10739
# [456]#011train-error:0.08862#011validation-error:0.10739
# [457]#011train-error:0.08858#011validation-error:0.10739
# [458]#011train-error:0.08872#011validation-error:0.10739
# [459]#011train-error:0.08869#011validation-error:0.10747
# [460]#011train-error:0.08869#011validation-error:0.10739
# [461]#011train-error:0.08869#011validation-error:0.10755
# [462]#011train-error:0.08872#011validation-error:0.10731
# [463]#011train-error:0.08862#011validation-error:0.10731
# [464]#011train-error:0.08865#011validation-error:0.10723
# [465]#011train-error:0.08865#011validation-error:0.10723
# [466]#011train-error:0.08858#011validation-error:0.10731
# [467]#011train-error:0.08845#011validation-error:0.10763
# [468]#011train-error:0.08838#011validation-error:0.10731
# [469]#011train-error:0.08834#011validation-error:0.10731
# [470]#011train-error:0.08845#011validation-error:0.10723
# [471]#011train-error:0.08865#011validation-error:0.10755
# [472]#011train-error:0.08852#011validation-error:0.10731
# [473]#011train-error:0.08852#011validation-error:0.10731
# [474]#011train-error:0.08858#011validation-error:0.10747
# [475]#011train-error:0.08862#011validation-error:0.10747
# [476]#011train-error:0.08852#011validation-error:0.10731
# [477]#011train-error:0.08855#011validation-error:0.10731
# [478]#011train-error:0.08841#011validation-error:0.10739
# [479]#011train-error:0.08834#011validation-error:0.10763
# [480]#011train-error:0.08841#011validation-error:0.10755
# [481]#011train-error:0.08834#011validation-error:0.10763
# [482]#011train-error:0.08858#011validation-error:0.10731
# [483]#011train-error:0.08838#011validation-error:0.10739
# [484]#011train-error:0.08834#011validation-error:0.10723
# [485]#011train-error:0.08831#011validation-error:0.10731
# [486]#011train-error:0.08820#011validation-error:0.10715
# [487]#011train-error:0.08820#011validation-error:0.10739
# [488]#011train-error:0.08824#011validation-error:0.10747
# [489]#011train-error:0.08820#011validation-error:0.10747
# [490]#011train-error:0.08820#011validation-error:0.10731
# [491]#011train-error:0.08807#011validation-error:0.10706
# [492]#011train-error:0.08800#011validation-error:0.10706
# [493]#011train-error:0.08800#011validation-error:0.10698
# [494]#011train-error:0.08800#011validation-error:0.10698
# [495]#011train-error:0.08800#011validation-error:0.10698
# [496]#011train-error:0.08807#011validation-error:0.10690
# [497]#011train-error:0.08800#011validation-error:0.10723
# [498]#011train-error:0.08796#011validation-error:0.10723
# [499]#011train-error:0.08796#011validation-error:0.10715
# [500]#011train-error:0.08786#011validation-error:0.10706
# [501]#011train-error:0.08779#011validation-error:0.10682
# [502]#011train-error:0.08803#011validation-error:0.10666
# [503]#011train-error:0.08817#011validation-error:0.10658
# [504]#011train-error:0.08793#011validation-error:0.10658
# [505]#011train-error:0.08803#011validation-error:0.10674
# [506]#011train-error:0.08810#011validation-error:0.10674
# [507]#011train-error:0.08810#011validation-error:0.10674
# [508]#011train-error:0.08813#011validation-error:0.10674
# [509]#011train-error:0.08786#011validation-error:0.10682
# [510]#011train-error:0.08786#011validation-error:0.10690
# [511]#011train-error:0.08793#011validation-error:0.10682
# [512]#011train-error:0.08793#011validation-error:0.10682
# [513]#011train-error:0.08793#011validation-error:0.10682
# [514]#011train-error:0.08786#011validation-error:0.10690
# [515]#011train-error:0.08793#011validation-error:0.10682
# [516]#011train-error:0.08789#011validation-error:0.10666
# [517]#011train-error:0.08786#011validation-error:0.10698
# [518]#011train-error:0.08786#011validation-error:0.10698
# [519]#011train-error:0.08800#011validation-error:0.10682
# [520]#011train-error:0.08803#011validation-error:0.10690
# [521]#011train-error:0.08803#011validation-error:0.10690
# [522]#011train-error:0.08803#011validation-error:0.10690
# [523]#011train-error:0.08793#011validation-error:0.10690
# [524]#011train-error:0.08803#011validation-error:0.10674
# [525]#011train-error:0.08803#011validation-error:0.10674
# [526]#011train-error:0.08803#011validation-error:0.10666
# [527]#011train-error:0.08810#011validation-error:0.10674
# [528]#011train-error:0.08786#011validation-error:0.10658
# [529]#011train-error:0.08786#011validation-error:0.10658
# [530]#011train-error:0.08772#011validation-error:0.10690
# [531]#011train-error:0.08772#011validation-error:0.10674
# [532]#011train-error:0.08779#011validation-error:0.10682
# [533]#011train-error:0.08772#011validation-error:0.10682
# [534]#011train-error:0.08779#011validation-error:0.10682
# [535]#011train-error:0.08772#011validation-error:0.10682
# [536]#011train-error:0.08772#011validation-error:0.10682
# [537]#011train-error:0.08741#011validation-error:0.10698
# [538]#011train-error:0.08741#011validation-error:0.10698
# [539]#011train-error:0.08741#011validation-error:0.10698
# [540]#011train-error:0.08758#011validation-error:0.10682
# [541]#011train-error:0.08765#011validation-error:0.10723
# [542]#011train-error:0.08758#011validation-error:0.10723
# [543]#011train-error:0.08761#011validation-error:0.10731
# [544]#011train-error:0.08765#011validation-error:0.10731
# [545]#011train-error:0.08761#011validation-error:0.10706
# [546]#011train-error:0.08761#011validation-error:0.10706
# [547]#011train-error:0.08761#011validation-error:0.10715
# [548]#011train-error:0.08772#011validation-error:0.10723
# [549]#011train-error:0.08779#011validation-error:0.10715
# [550]#011train-error:0.08775#011validation-error:0.10715
# [551]#011train-error:0.08768#011validation-error:0.10723
# [552]#011train-error:0.08775#011validation-error:0.10723
# [553]#011train-error:0.08761#011validation-error:0.10723
# [554]#011train-error:0.08765#011validation-error:0.10715
# [555]#011train-error:0.08747#011validation-error:0.10771
# [556]#011train-error:0.08761#011validation-error:0.10763
# [557]#011train-error:0.08744#011validation-error:0.10731
# [558]#011train-error:0.08747#011validation-error:0.10723
# [559]#011train-error:0.08761#011validation-error:0.10723
# [560]#011train-error:0.08747#011validation-error:0.10739
# [561]#011train-error:0.08775#011validation-error:0.10771
# [562]#011train-error:0.08768#011validation-error:0.10755
# [563]#011train-error:0.08786#011validation-error:0.10763
# [564]#011train-error:0.08793#011validation-error:0.10771
# [565]#011train-error:0.08793#011validation-error:0.10779
# [566]#011train-error:0.08779#011validation-error:0.10787
# [567]#011train-error:0.08761#011validation-error:0.10763
# [568]#011train-error:0.08754#011validation-error:0.10755
# [569]#011train-error:0.08761#011validation-error:0.10755
# [570]#011train-error:0.08758#011validation-error:0.10755
# [571]#011train-error:0.08765#011validation-error:0.10771
# [572]#011train-error:0.08744#011validation-error:0.10763
# [573]#011train-error:0.08744#011validation-error:0.10763
# [574]#011train-error:0.08734#011validation-error:0.10731
# [575]#011train-error:0.08730#011validation-error:0.10715
# [576]#011train-error:0.08723#011validation-error:0.10682
# [577]#011train-error:0.08734#011validation-error:0.10698
# [578]#011train-error:0.08727#011validation-error:0.10690
# [579]#011train-error:0.08730#011validation-error:0.10698
# [580]#011train-error:0.08720#011validation-error:0.10723
# [581]#011train-error:0.08699#011validation-error:0.10739
# [582]#011train-error:0.08699#011validation-error:0.10739
# [583]#011train-error:0.08702#011validation-error:0.10771
# [584]#011train-error:0.08716#011validation-error:0.10771
# [585]#011train-error:0.08713#011validation-error:0.10795
# [586]#011train-error:0.08720#011validation-error:0.10787
# [587]#011train-error:0.08734#011validation-error:0.10779
# [588]#011train-error:0.08737#011validation-error:0.10787
# [589]#011train-error:0.08734#011validation-error:0.10787
# [590]#011train-error:0.08730#011validation-error:0.10763
# [591]#011train-error:0.08727#011validation-error:0.10763
# [592]#011train-error:0.08730#011validation-error:0.10763
# [593]#011train-error:0.08723#011validation-error:0.10804
# [594]#011train-error:0.08709#011validation-error:0.10795
# [595]#011train-error:0.08723#011validation-error:0.10771
# [596]#011train-error:0.08699#011validation-error:0.10779
# [597]#011train-error:0.08709#011validation-error:0.10763
# [598]#011train-error:0.08709#011validation-error:0.10763
# [599]#011train-error:0.08727#011validation-error:0.10739
# [600]#011train-error:0.08689#011validation-error:0.10723
# [601]#011train-error:0.08689#011validation-error:0.10723
# [602]#011train-error:0.08661#011validation-error:0.10731
# [603]#011train-error:0.08709#011validation-error:0.10715
# [604]#011train-error:0.08723#011validation-error:0.10723
# [605]#011train-error:0.08706#011validation-error:0.10715
# [606]#011train-error:0.08730#011validation-error:0.10747
# [607]#011train-error:0.08734#011validation-error:0.10747
# [608]#011train-error:0.08734#011validation-error:0.10747
# [609]#011train-error:0.08730#011validation-error:0.10747
# [610]#011train-error:0.08716#011validation-error:0.10755
# [611]#011train-error:0.08696#011validation-error:0.10755
# [612]#011train-error:0.08699#011validation-error:0.10747
# [613]#011train-error:0.08709#011validation-error:0.10771
# [614]#011train-error:0.08720#011validation-error:0.10763
# [615]#011train-error:0.08716#011validation-error:0.10739
# [616]#011train-error:0.08713#011validation-error:0.10747
# [617]#011train-error:0.08713#011validation-error:0.10747
# [618]#011train-error:0.08706#011validation-error:0.10755
# [619]#011train-error:0.08713#011validation-error:0.10747
# [620]#011train-error:0.08713#011validation-error:0.10747
# [621]#011train-error:0.08713#011validation-error:0.10755
# [622]#011train-error:0.08713#011validation-error:0.10731
# [623]#011train-error:0.08716#011validation-error:0.10731
# [624]#011train-error:0.08720#011validation-error:0.10706
# [625]#011train-error:0.08720#011validation-error:0.10739
# [626]#011train-error:0.08727#011validation-error:0.10755
# [627]#011train-error:0.08727#011validation-error:0.10747
# [628]#011train-error:0.08727#011validation-error:0.10747
# [629]#011train-error:0.08730#011validation-error:0.10706
# [630]#011train-error:0.08730#011validation-error:0.10706
# [631]#011train-error:0.08727#011validation-error:0.10706
# [632]#011train-error:0.08744#011validation-error:0.10771
# [633]#011train-error:0.08723#011validation-error:0.10739
# [634]#011train-error:0.08723#011validation-error:0.10755
# [635]#011train-error:0.08723#011validation-error:0.10739
# [636]#011train-error:0.08699#011validation-error:0.10755
# [637]#011train-error:0.08709#011validation-error:0.10755
# [638]#011train-error:0.08699#011validation-error:0.10747
# [639]#011train-error:0.08702#011validation-error:0.10747
# [640]#011train-error:0.08699#011validation-error:0.10763
# [641]#011train-error:0.08696#011validation-error:0.10755
# [642]#011train-error:0.08699#011validation-error:0.10731
# [643]#011train-error:0.08699#011validation-error:0.10747
# [644]#011train-error:0.08702#011validation-error:0.10747
# [645]#011train-error:0.08713#011validation-error:0.10755
# [646]#011train-error:0.08713#011validation-error:0.10763
# [647]#011train-error:0.08716#011validation-error:0.10763
# [648]#011train-error:0.08692#011validation-error:0.10706
# [649]#011train-error:0.08692#011validation-error:0.10706
# [650]#011train-error:0.08692#011validation-error:0.10706
# [651]#011train-error:0.08696#011validation-error:0.10731
# [652]#011train-error:0.08692#011validation-error:0.10731
# [653]#011train-error:0.08685#011validation-error:0.10731
# [654]#011train-error:0.08675#011validation-error:0.10723
# [655]#011train-error:0.08682#011validation-error:0.10723
# [656]#011train-error:0.08675#011validation-error:0.10723
# [657]#011train-error:0.08664#011validation-error:0.10706
# [658]#011train-error:0.08661#011validation-error:0.10698
# [659]#011train-error:0.08657#011validation-error:0.10698
# [660]#011train-error:0.08668#011validation-error:0.10698
# [661]#011train-error:0.08657#011validation-error:0.10698
# [662]#011train-error:0.08671#011validation-error:0.10682
# [663]#011train-error:0.08650#011validation-error:0.10706
# [664]#011train-error:0.08647#011validation-error:0.10706
# [665]#011train-error:0.08640#011validation-error:0.10715
# [666]#011train-error:0.08640#011validation-error:0.10715
# [667]#011train-error:0.08636#011validation-error:0.10706
# [668]#011train-error:0.08619#011validation-error:0.10706
# [669]#011train-error:0.08626#011validation-error:0.10706
# [670]#011train-error:0.08623#011validation-error:0.10706
# [671]#011train-error:0.08623#011validation-error:0.10698
# [672]#011train-error:0.08612#011validation-error:0.10706
# [673]#011train-error:0.08640#011validation-error:0.10682
# [674]#011train-error:0.08647#011validation-error:0.10682
# [675]#011train-error:0.08647#011validation-error:0.10682
# [676]#011train-error:0.08650#011validation-error:0.10674
# [677]#011train-error:0.08675#011validation-error:0.10698
# [678]#011train-error:0.08671#011validation-error:0.10698
# [679]#011train-error:0.08664#011validation-error:0.10706
# [680]#011train-error:0.08661#011validation-error:0.10747
# [681]#011train-error:0.08668#011validation-error:0.10747
# [682]#011train-error:0.08650#011validation-error:0.10755
# [683]#011train-error:0.08654#011validation-error:0.10763
# [684]#011train-error:0.08654#011validation-error:0.10763
# [685]#011train-error:0.08661#011validation-error:0.10755
# [686]#011train-error:0.08682#011validation-error:0.10715
# [687]#011train-error:0.08664#011validation-error:0.10723
# [688]#011train-error:0.08636#011validation-error:0.10731
# [689]#011train-error:0.08640#011validation-error:0.10731
# [690]#011train-error:0.08643#011validation-error:0.10731
# [691]#011train-error:0.08650#011validation-error:0.10706
# [692]#011train-error:0.08633#011validation-error:0.10698
# [693]#011train-error:0.08619#011validation-error:0.10706
# [694]#011train-error:0.08630#011validation-error:0.10706
# [695]#011train-error:0.08602#011validation-error:0.10682
# [696]#011train-error:0.08602#011validation-error:0.10706
# [697]#011train-error:0.08602#011validation-error:0.10690
# [698]#011train-error:0.08598#011validation-error:0.10682
# [699]#011train-error:0.08605#011validation-error:0.10698
# [700]#011train-error:0.08585#011validation-error:0.10731
# [701]#011train-error:0.08623#011validation-error:0.10706
# [702]#011train-error:0.08626#011validation-error:0.10723
# [703]#011train-error:0.08636#011validation-error:0.10723
# [704]#011train-error:0.08626#011validation-error:0.10715
# [705]#011train-error:0.08636#011validation-error:0.10731
# [706]#011train-error:0.08636#011validation-error:0.10723
# [707]#011train-error:0.08616#011validation-error:0.10731
# [708]#011train-error:0.08633#011validation-error:0.10747
# [709]#011train-error:0.08612#011validation-error:0.10706
# [710]#011train-error:0.08616#011validation-error:0.10706
# [711]#011train-error:0.08612#011validation-error:0.10706
# [712]#011train-error:0.08616#011validation-error:0.10706
# [713]#011train-error:0.08626#011validation-error:0.10715
# [714]#011train-error:0.08623#011validation-error:0.10715
# [715]#011train-error:0.08626#011validation-error:0.10715
# [716]#011train-error:0.08626#011validation-error:0.10723
# [717]#011train-error:0.08636#011validation-error:0.10723
# [718]#011train-error:0.08636#011validation-error:0.10723
# [719]#011train-error:0.08636#011validation-error:0.10723
# [720]#011train-error:0.08640#011validation-error:0.10723
# [721]#011train-error:0.08643#011validation-error:0.10715
# [722]#011train-error:0.08616#011validation-error:0.10715
# [723]#011train-error:0.08640#011validation-error:0.10731
# [724]#011train-error:0.08636#011validation-error:0.10715
# [725]#011train-error:0.08636#011validation-error:0.10715
# [726]#011train-error:0.08633#011validation-error:0.10715
# [727]#011train-error:0.08657#011validation-error:0.10706
# [728]#011train-error:0.08650#011validation-error:0.10706
# [729]#011train-error:0.08640#011validation-error:0.10731
# [730]#011train-error:0.08633#011validation-error:0.10723
# [731]#011train-error:0.08647#011validation-error:0.10706
# [732]#011train-error:0.08609#011validation-error:0.10723
# [733]#011train-error:0.08626#011validation-error:0.10682
# [734]#011train-error:0.08626#011validation-error:0.10690
# [735]#011train-error:0.08626#011validation-error:0.10731
# [736]#011train-error:0.08630#011validation-error:0.10723
# [737]#011train-error:0.08626#011validation-error:0.10731
# [738]#011train-error:0.08626#011validation-error:0.10731
# [739]#011train-error:0.08623#011validation-error:0.10731
# [740]#011train-error:0.08623#011validation-error:0.10731
# [741]#011train-error:0.08623#011validation-error:0.10739
# [742]#011train-error:0.08630#011validation-error:0.10731
# [743]#011train-error:0.08633#011validation-error:0.10747
# [744]#011train-error:0.08650#011validation-error:0.10747
# [745]#011train-error:0.08626#011validation-error:0.10731
# [746]#011train-error:0.08633#011validation-error:0.10731
# [747]#011train-error:0.08609#011validation-error:0.10706
# [748]#011train-error:0.08609#011validation-error:0.10715
# [749]#011train-error:0.08619#011validation-error:0.10706
# [750]#011train-error:0.08609#011validation-error:0.10715
# [751]#011train-error:0.08602#011validation-error:0.10698
# [752]#011train-error:0.08605#011validation-error:0.10698
# [753]#011train-error:0.08612#011validation-error:0.10682
# [754]#011train-error:0.08605#011validation-error:0.10739
# [755]#011train-error:0.08602#011validation-error:0.10731
# [756]#011train-error:0.08591#011validation-error:0.10731
# [757]#011train-error:0.08595#011validation-error:0.10739
# [758]#011train-error:0.08595#011validation-error:0.10747
# [759]#011train-error:0.08591#011validation-error:0.10771
# [760]#011train-error:0.08598#011validation-error:0.10763
# [761]#011train-error:0.08591#011validation-error:0.10763
# [762]#011train-error:0.08591#011validation-error:0.10763
# [763]#011train-error:0.08605#011validation-error:0.10747
# [764]#011train-error:0.08595#011validation-error:0.10715
# [765]#011train-error:0.08605#011validation-error:0.10747
# [766]#011train-error:0.08612#011validation-error:0.10747
# [767]#011train-error:0.08605#011validation-error:0.10739
# [768]#011train-error:0.08623#011validation-error:0.10763
# [769]#011train-error:0.08633#011validation-error:0.10763
# [770]#011train-error:0.08602#011validation-error:0.10723
# [771]#011train-error:0.08602#011validation-error:0.10723
# [772]#011train-error:0.08591#011validation-error:0.10715
# [773]#011train-error:0.08588#011validation-error:0.10715
# [774]#011train-error:0.08591#011validation-error:0.10739
# [775]#011train-error:0.08595#011validation-error:0.10755
# [776]#011train-error:0.08602#011validation-error:0.10771
# [777]#011train-error:0.08591#011validation-error:0.10739
# [778]#011train-error:0.08605#011validation-error:0.10747
# [779]#011train-error:0.08605#011validation-error:0.10747
# [780]#011train-error:0.08612#011validation-error:0.10739
# [781]#011train-error:0.08602#011validation-error:0.10739
# [782]#011train-error:0.08605#011validation-error:0.10731
# [783]#011train-error:0.08605#011validation-error:0.10739
# [784]#011train-error:0.08595#011validation-error:0.10755
# [785]#011train-error:0.08588#011validation-error:0.10771
# [786]#011train-error:0.08585#011validation-error:0.10763
# [787]#011train-error:0.08588#011validation-error:0.10755
# [788]#011train-error:0.08595#011validation-error:0.10715
# [789]#011train-error:0.08623#011validation-error:0.10763
# [790]#011train-error:0.08633#011validation-error:0.10763
# [791]#011train-error:0.08623#011validation-error:0.10763
# [792]#011train-error:0.08602#011validation-error:0.10787
# [793]#011train-error:0.08567#011validation-error:0.10812
# [794]#011train-error:0.08571#011validation-error:0.10812
# [795]#011train-error:0.08574#011validation-error:0.10828
# [796]#011train-error:0.08574#011validation-error:0.10828
# [797]#011train-error:0.08574#011validation-error:0.10820
# [798]#011train-error:0.08567#011validation-error:0.10820
# [799]#011train-error:0.08564#011validation-error:0.10820
# [800]#011train-error:0.08564#011validation-error:0.10820
# [801]#011train-error:0.08564#011validation-error:0.10820
# [802]#011train-error:0.08571#011validation-error:0.10795
# [803]#011train-error:0.08560#011validation-error:0.10795
# [804]#011train-error:0.08571#011validation-error:0.10804
# [805]#011train-error:0.08571#011validation-error:0.10804
# [806]#011train-error:0.08560#011validation-error:0.10795
# [807]#011train-error:0.08574#011validation-error:0.10795
# [808]#011train-error:0.08571#011validation-error:0.10812
# [809]#011train-error:0.08571#011validation-error:0.10812
# [810]#011train-error:0.08571#011validation-error:0.10812
# [811]#011train-error:0.08571#011validation-error:0.10804
# [812]#011train-error:0.08574#011validation-error:0.10812
# [813]#011train-error:0.08571#011validation-error:0.10812
# [814]#011train-error:0.08578#011validation-error:0.10812
# [815]#011train-error:0.08581#011validation-error:0.10812
# [816]#011train-error:0.08581#011validation-error:0.10812
# [817]#011train-error:0.08574#011validation-error:0.10795
# [818]#011train-error:0.08574#011validation-error:0.10795
# [819]#011train-error:0.08581#011validation-error:0.10804
# [820]#011train-error:0.08578#011validation-error:0.10795
# [821]#011train-error:0.08578#011validation-error:0.10795
# [822]#011train-error:0.08581#011validation-error:0.10795
# [823]#011train-error:0.08581#011validation-error:0.10779
# [824]#011train-error:0.08571#011validation-error:0.10747
# [825]#011train-error:0.08571#011validation-error:0.10747
# [826]#011train-error:0.08571#011validation-error:0.10747
# [827]#011train-error:0.08574#011validation-error:0.10747
# [828]#011train-error:0.08567#011validation-error:0.10731
# [829]#011train-error:0.08567#011validation-error:0.10739
# [830]#011train-error:0.08564#011validation-error:0.10731
# [831]#011train-error:0.08581#011validation-error:0.10731
# [832]#011train-error:0.08574#011validation-error:0.10739
# [833]#011train-error:0.08578#011validation-error:0.10755
# [834]#011train-error:0.08585#011validation-error:0.10763
# [835]#011train-error:0.08553#011validation-error:0.10747
# [836]#011train-error:0.08560#011validation-error:0.10755
# [837]#011train-error:0.08557#011validation-error:0.10747
# [838]#011train-error:0.08553#011validation-error:0.10747
# [839]#011train-error:0.08550#011validation-error:0.10723
# [840]#011train-error:0.08550#011validation-error:0.10731
# [841]#011train-error:0.08546#011validation-error:0.10731
# [842]#011train-error:0.08550#011validation-error:0.10723
# [843]#011train-error:0.08529#011validation-error:0.10747
# [844]#011train-error:0.08543#011validation-error:0.10747
# [845]#011train-error:0.08532#011validation-error:0.10747
# [846]#011train-error:0.08525#011validation-error:0.10763
# [847]#011train-error:0.08539#011validation-error:0.10763
# [848]#011train-error:0.08536#011validation-error:0.10771
# [849]#011train-error:0.08532#011validation-error:0.10755
# [850]#011train-error:0.08550#011validation-error:0.10779
# [851]#011train-error:0.08546#011validation-error:0.10787
# [852]#011train-error:0.08546#011validation-error:0.10787
# [853]#011train-error:0.08550#011validation-error:0.10787
# [854]#011train-error:0.08550#011validation-error:0.10787
# [855]#011train-error:0.08543#011validation-error:0.10779
# [856]#011train-error:0.08550#011validation-error:0.10771
# [857]#011train-error:0.08550#011validation-error:0.10763
# [858]#011train-error:0.08539#011validation-error:0.10779
# [859]#011train-error:0.08536#011validation-error:0.10779
# [860]#011train-error:0.08543#011validation-error:0.10771
# [861]#011train-error:0.08522#011validation-error:0.10747
# [862]#011train-error:0.08519#011validation-error:0.10755
# [863]#011train-error:0.08529#011validation-error:0.10779
# [864]#011train-error:0.08532#011validation-error:0.10779
# [865]#011train-error:0.08532#011validation-error:0.10779
# [866]#011train-error:0.08525#011validation-error:0.10779
# [867]#011train-error:0.08543#011validation-error:0.10763
# [868]#011train-error:0.08543#011validation-error:0.10763
# [869]#011train-error:0.08546#011validation-error:0.10747
# [870]#011train-error:0.08543#011validation-error:0.10755
# [871]#011train-error:0.08539#011validation-error:0.10747
# [872]#011train-error:0.08522#011validation-error:0.10698
# [873]#011train-error:0.08522#011validation-error:0.10706
# [874]#011train-error:0.08522#011validation-error:0.10706
# [875]#011train-error:0.08522#011validation-error:0.10715
# [876]#011train-error:0.08529#011validation-error:0.10715
# [877]#011train-error:0.08529#011validation-error:0.10723
# [878]#011train-error:0.08532#011validation-error:0.10715
# [879]#011train-error:0.08529#011validation-error:0.10715
# [880]#011train-error:0.08539#011validation-error:0.10723
# [881]#011train-error:0.08532#011validation-error:0.10723
# [882]#011train-error:0.08543#011validation-error:0.10731
# [883]#011train-error:0.08539#011validation-error:0.10755
# [884]#011train-error:0.08557#011validation-error:0.10755
# [885]#011train-error:0.08536#011validation-error:0.10755
# [886]#011train-error:0.08560#011validation-error:0.10755
# [887]#011train-error:0.08560#011validation-error:0.10755
# [888]#011train-error:0.08553#011validation-error:0.10723
# [889]#011train-error:0.08567#011validation-error:0.10739
# [890]#011train-error:0.08560#011validation-error:0.10763
# [891]#011train-error:0.08560#011validation-error:0.10763
# [892]#011train-error:0.08560#011validation-error:0.10763
# [893]#011train-error:0.08553#011validation-error:0.10747
# [894]#011train-error:0.08546#011validation-error:0.10731
# [895]#011train-error:0.08550#011validation-error:0.10755
# [896]#011train-error:0.08543#011validation-error:0.10763
# [897]#011train-error:0.08543#011validation-error:0.10763
# [898]#011train-error:0.08543#011validation-error:0.10763
# [899]#011train-error:0.08539#011validation-error:0.10763
# [900]#011train-error:0.08546#011validation-error:0.10747
# [901]#011train-error:0.08543#011validation-error:0.10763
# [902]#011train-error:0.08543#011validation-error:0.10747
# [903]#011train-error:0.08546#011validation-error:0.10747
# [904]#011train-error:0.08543#011validation-error:0.10755
# [905]#011train-error:0.08546#011validation-error:0.10755
# [906]#011train-error:0.08539#011validation-error:0.10755
# [907]#011train-error:0.08557#011validation-error:0.10747
# [908]#011train-error:0.08564#011validation-error:0.10747
# [909]#011train-error:0.08557#011validation-error:0.10747
# [910]#011train-error:0.08557#011validation-error:0.10747
# [911]#011train-error:0.08550#011validation-error:0.10747
# [912]#011train-error:0.08557#011validation-error:0.10779
# [913]#011train-error:0.08560#011validation-error:0.10771
# [914]#011train-error:0.08539#011validation-error:0.10779
# [915]#011train-error:0.08543#011validation-error:0.10779
# [916]#011train-error:0.08501#011validation-error:0.10787
# [917]#011train-error:0.08525#011validation-error:0.10804
# [918]#011train-error:0.08529#011validation-error:0.10795
# [919]#011train-error:0.08532#011validation-error:0.10779
# [920]#011train-error:0.08543#011validation-error:0.10795
# [921]#011train-error:0.08553#011validation-error:0.10795
# [922]#011train-error:0.08550#011validation-error:0.10795
# [923]#011train-error:0.08560#011validation-error:0.10795
# [924]#011train-error:0.08550#011validation-error:0.10804
# [925]#011train-error:0.08525#011validation-error:0.10795
# [926]#011train-error:0.08532#011validation-error:0.10804
# [927]#011train-error:0.08532#011validation-error:0.10795
# [928]#011train-error:0.08532#011validation-error:0.10812
# [929]#011train-error:0.08550#011validation-error:0.10804
# [930]#011train-error:0.08525#011validation-error:0.10795
# [931]#011train-error:0.08529#011validation-error:0.10787
# [932]#011train-error:0.08536#011validation-error:0.10795
# [933]#011train-error:0.08532#011validation-error:0.10795
# [934]#011train-error:0.08529#011validation-error:0.10820
# [935]#011train-error:0.08529#011validation-error:0.10820
# [936]#011train-error:0.08529#011validation-error:0.10820
# [937]#011train-error:0.08529#011validation-error:0.10820
# [938]#011train-error:0.08519#011validation-error:0.10812
# [939]#011train-error:0.08525#011validation-error:0.10836
# [940]#011train-error:0.08525#011validation-error:0.10828
# [941]#011train-error:0.08525#011validation-error:0.10812
# [942]#011train-error:0.08494#011validation-error:0.10804
# [943]#011train-error:0.08529#011validation-error:0.10739
# [944]#011train-error:0.08525#011validation-error:0.10739
# [945]#011train-error:0.08501#011validation-error:0.10739
# [946]#011train-error:0.08498#011validation-error:0.10747
# [947]#011train-error:0.08508#011validation-error:0.10747
# [948]#011train-error:0.08508#011validation-error:0.10739
# [949]#011train-error:0.08508#011validation-error:0.10747
# [950]#011train-error:0.08515#011validation-error:0.10747
# [951]#011train-error:0.08519#011validation-error:0.10739
# [952]#011train-error:0.08498#011validation-error:0.10747
# [953]#011train-error:0.08494#011validation-error:0.10747
# [954]#011train-error:0.08494#011validation-error:0.10771
# [955]#011train-error:0.08491#011validation-error:0.10779
# [956]#011train-error:0.08494#011validation-error:0.10779
# [957]#011train-error:0.08498#011validation-error:0.10747
# [958]#011train-error:0.08494#011validation-error:0.10747
# [959]#011train-error:0.08487#011validation-error:0.10739
# [960]#011train-error:0.08487#011validation-error:0.10739
# [961]#011train-error:0.08491#011validation-error:0.10739
# [962]#011train-error:0.08491#011validation-error:0.10755
# [963]#011train-error:0.08484#011validation-error:0.10779
# [964]#011train-error:0.08467#011validation-error:0.10804
# [965]#011train-error:0.08467#011validation-error:0.10804
# [966]#011train-error:0.08474#011validation-error:0.10804
# [967]#011train-error:0.08474#011validation-error:0.10836
# [968]#011train-error:0.08477#011validation-error:0.10804
# [969]#011train-error:0.08470#011validation-error:0.10779
# [970]#011train-error:0.08484#011validation-error:0.10836
# [971]#011train-error:0.08470#011validation-error:0.10779
# [972]#011train-error:0.08474#011validation-error:0.10779
# [973]#011train-error:0.08474#011validation-error:0.10779
# [974]#011train-error:0.08474#011validation-error:0.10771
# [975]#011train-error:0.08481#011validation-error:0.10795
# [976]#011train-error:0.08484#011validation-error:0.10787
# [977]#011train-error:0.08487#011validation-error:0.10787
# [978]#011train-error:0.08481#011validation-error:0.10787
# [979]#011train-error:0.08481#011validation-error:0.10787
# [980]#011train-error:0.08477#011validation-error:0.10804
# [981]#011train-error:0.08477#011validation-error:0.10787
# [982]#011train-error:0.08494#011validation-error:0.10804
# [983]#011train-error:0.08474#011validation-error:0.10804
# [984]#011train-error:0.08491#011validation-error:0.10812
# [985]#011train-error:0.08470#011validation-error:0.10804
# [986]#011train-error:0.08484#011validation-error:0.10787
# [987]#011train-error:0.08484#011validation-error:0.10779
# [988]#011train-error:0.08491#011validation-error:0.10771
# [989]#011train-error:0.08501#011validation-error:0.10795
# [990]#011train-error:0.08494#011validation-error:0.10787
# [991]#011train-error:0.08491#011validation-error:0.10763
# [992]#011train-error:0.08505#011validation-error:0.10747
# [993]#011train-error:0.08487#011validation-error:0.10787
# [994]#011train-error:0.08487#011validation-error:0.10787
# [995]#011train-error:0.08494#011validation-error:0.10812
# [996]#011train-error:0.08487#011validation-error:0.10795
# [997]#011train-error:0.08484#011validation-error:0.10795
# [998]#011train-error:0.08484#011validation-error:0.10795
# [999]#011train-error:0.08501#011validation-error:0.10828
#
# 2022-12-29 16:17:13 Uploading - Uploading generated training model
# 2022-12-29 16:17:13 Completed - Training job completed
# Training seconds: 178
# Billable seconds: 178

# %%
rule_output_path = xgb_model.output_path + "/" + xgb_model.latest_training_job.job_name + "/rule-output"
! aws s3 ls {rule_output_path} --recursive

# %%
xgb_model.output_path

# %%
output_path

# %%
xgb_model.latest_training_job.job_name

# %%
xgb_model

# %%
! aws s3 ls {rule_output_path} --recursive

# %%
# from IPython.display import FileLink, FileLinks
# display("Click link below to view the XGBoost Training report", FileLink("CreateXgboostReport/xgboost_report.html"))

# %%
xgb_model.model_data
# Out:
# 's3://sagemaker-us-east-1-432547830124/xgboost-as-a-built-in-algo/xgboost_model/sagemaker-xgboost-2022-12-29-16-11-47-930/output/model.tar.gz'

# %%
from sagemaker.serializers import CSVSerializer

# %%
xgb_model.deploy(
    initial_instance_count=1,
    instance_type='ml.t2.medium',
    serializer=CSVSerializer()
)
# Out:
# INFO:sagemaker:Creating model with name: sagemaker-xgboost-2022-12-29-16-19-07-866
# INFO:sagemaker:Creating endpoint-config with name sagemaker-xgboost-2022-12-29-16-19-07-866
# INFO:sagemaker:Creating endpoint with name sagemaker-xgboost-2022-12-29-16-19-07-866
# --------------!

# %%
'sagemaker-xgboost-2022-12-29-16-19-07-866'.endpoint_name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_17151/1740395619.py in <cell line: 1>()
# ----> 1 'sagemaker-xgboost-2022-12-29-16-19-07-866'.endpoint_name
#
# AttributeError: 'str' object has no attribute 'endpoint_name'

# %%
# Create a low-level SageMaker service client.
sagemaker_client = boto3.client('sagemaker')

# Delete endpoint
sagemaker_client.delete_endpoint(EndpointName='sagemaker-xgboost-2022-12-29-16-19-07-866')
# Out:
# INFO:botocore.credentials:Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole
# {'ResponseMetadata': {'RequestId': '573141c7-f6bd-45f2-8bde-adc3601a148a',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '573141c7-f6bd-45f2-8bde-adc3601a148a',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '0',
#    'date': 'Thu, 29 Dec 2022 16:42:06 GMT'},
#   'RetryAttempts': 0}}

# %%
# Delete endpoint configuration
sagemaker_client.delete_endpoint_config(EndpointConfigName='sagemaker-xgboost-2022-12-29-16-19-07-866')
# Out:
# {'ResponseMetadata': {'RequestId': '19898e6d-9d82-4a56-bf08-f39568504f12',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '19898e6d-9d82-4a56-bf08-f39568504f12',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '0',
#    'date': 'Thu, 29 Dec 2022 16:42:57 GMT'},
#   'RetryAttempts': 0}}

# %%
sagemaker_client.delete_model(ModelName='sagemaker-xgboost-2022-12-29-16-19-07-866')
# Out:
# {'ResponseMetadata': {'RequestId': '0410022f-cc45-40dc-9acd-89434a3f37cc',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '0410022f-cc45-40dc-9acd-89434a3f37cc',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '0',
#    'date': 'Thu, 29 Dec 2022 16:44:02 GMT'},
#   'RetryAttempts': 0}}
